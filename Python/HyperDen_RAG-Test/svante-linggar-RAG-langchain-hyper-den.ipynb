# %% [markdown]
# # 1. Install all the necessary libraries

# %%
# !pip install langchain langchain-openai python-dotenv

# %%
pip install langchain

# %%
pip install langchain langgraph langchain-openai langchain-community chromadb tiktoken

# %%
pip install sentence-transformers
# Out:
# Collecting sentence-transformers
#   Downloading sentence_transformers-5.3.0-py3-none-any.whl.metadata (16 kB)
# Collecting transformers<6.0.0,>=4.41.0 (from sentence-transformers)
#   Downloading transformers-5.5.1-py3-none-any.whl.metadata (32 kB)
# Collecting huggingface-hub>=0.20.0 (from sentence-transformers)
#   Downloading huggingface_hub-1.9.2-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: torch>=1.11.0 in /opt/anaconda3/lib/python3.13/site-packages (from sentence-transformers) (2.9.0)
# Requirement already satisfied: numpy in /opt/anaconda3/lib/python3.13/site-packages (from sentence-transformers) (2.1.3)
# Requirement already satisfied: scikit-learn in /opt/anaconda3/lib/python3.13/site-packages (from sentence-transformers) (1.6.1)
# Requirement already satisfied: scipy in /opt/anaconda3/lib/python3.13/site-packages (from sentence-transformers) (1.15.3)
# Requirement already satisfied: typing_extensions>=4.5.0 in /opt/anaconda3/lib/python3.13/site-packages (from sentence-transformers) (4.15.0)
# Requirement already satisfied: tqdm in /opt/anaconda3/lib/python3.13/site-packages (from sentence-transformers) (4.67.1)
# Requirement already satisfied: packaging>=20.0 in /opt/anaconda3/lib/python3.13/site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /opt/anaconda3/lib/python3.13/site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (6.0.2)
# Collecting regex>=2025.10.22 (from transformers<6.0.0,>=4.41.0->sentence-transformers)
#   Downloading regex-2026.4.4-cp313-cp313-macosx_11_0_arm64.whl.metadata (40 kB)
# Collecting tokenizers<=0.23.0,>=0.22.0 (from transformers<6.0.0,>=4.41.0->sentence-transformers)
#   Downloading tokenizers-0.22.2-cp39-abi3-macosx_11_0_arm64.whl.metadata (7.3 kB)
# Requirement already satisfied: typer in /opt/anaconda3/lib/python3.13/site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (0.9.0)
# Collecting safetensors>=0.4.3 (from transformers<6.0.0,>=4.41.0->sentence-transformers)
#   Downloading safetensors-0.7.0-cp38-abi3-macosx_11_0_arm64.whl.metadata (4.1 kB)
# Requirement already satisfied: filelock>=3.10.0 in /opt/anaconda3/lib/python3.13/site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (3.17.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /opt/anaconda3/lib/python3.13/site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (2025.3.2)
# Collecting hf-xet<2.0.0,>=1.4.3 (from huggingface-hub>=0.20.0->sentence-transformers)
#   Downloading hf_xet-1.4.3-cp37-abi3-macosx_11_0_arm64.whl.metadata (4.9 kB)
# Requirement already satisfied: httpx<1,>=0.23.0 in /opt/anaconda3/lib/python3.13/site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (0.28.1)
# Requirement already satisfied: anyio in /opt/anaconda3/lib/python3.13/site-packages (from httpx<1,>=0.23.0->huggingface-hub>=0.20.0->sentence-transformers) (4.7.0)
# Requirement already satisfied: certifi in /opt/anaconda3/lib/python3.13/site-packages (from httpx<1,>=0.23.0->huggingface-hub>=0.20.0->sentence-transformers) (2025.10.5)
# Requirement already satisfied: httpcore==1.* in /opt/anaconda3/lib/python3.13/site-packages (from httpx<1,>=0.23.0->huggingface-hub>=0.20.0->sentence-transformers) (1.0.9)
# Requirement already satisfied: idna in /opt/anaconda3/lib/python3.13/site-packages (from httpx<1,>=0.23.0->huggingface-hub>=0.20.0->sentence-transformers) (3.7)
# Requirement already satisfied: h11>=0.16 in /opt/anaconda3/lib/python3.13/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface-hub>=0.20.0->sentence-transformers) (0.16.0)
# Requirement already satisfied: setuptools in /opt/anaconda3/lib/python3.13/site-packages (from torch>=1.11.0->sentence-transformers) (72.1.0)
# Requirement already satisfied: sympy>=1.13.3 in /opt/anaconda3/lib/python3.13/site-packages (from torch>=1.11.0->sentence-transformers) (1.13.3)
# Requirement already satisfied: networkx>=2.5.1 in /opt/anaconda3/lib/python3.13/site-packages (from torch>=1.11.0->sentence-transformers) (3.4.2)
# Requirement already satisfied: jinja2 in /opt/anaconda3/lib/python3.13/site-packages (from torch>=1.11.0->sentence-transformers) (3.1.6)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/anaconda3/lib/python3.13/site-packages (from sympy>=1.13.3->torch>=1.11.0->sentence-transformers) (1.3.0)
# Requirement already satisfied: sniffio>=1.1 in /opt/anaconda3/lib/python3.13/site-packages (from anyio->httpx<1,>=0.23.0->huggingface-hub>=0.20.0->sentence-transformers) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/anaconda3/lib/python3.13/site-packages (from jinja2->torch>=1.11.0->sentence-transformers) (3.0.2)
# Requirement already satisfied: joblib>=1.2.0 in /opt/anaconda3/lib/python3.13/site-packages (from scikit-learn->sentence-transformers) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /opt/anaconda3/lib/python3.13/site-packages (from scikit-learn->sentence-transformers) (3.5.0)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /opt/anaconda3/lib/python3.13/site-packages (from typer->transformers<6.0.0,>=4.41.0->sentence-transformers) (8.3.1)
# Downloading sentence_transformers-5.3.0-py3-none-any.whl (512 kB)
# Downloading transformers-5.5.1-py3-none-any.whl (10.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.2/10.2 MB 30.8 MB/s eta 0:00:00 0:00:01
# Downloading huggingface_hub-1.9.2-py3-none-any.whl (637 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 637.3/637.3 kB 20.2 MB/s eta 0:00:00
# Downloading hf_xet-1.4.3-cp37-abi3-macosx_11_0_arm64.whl (3.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 21.4 MB/s eta 0:00:00
# Downloading tokenizers-0.22.2-cp39-abi3-macosx_11_0_arm64.whl (3.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 23.7 MB/s eta 0:00:00
# Downloading regex-2026.4.4-cp313-cp313-macosx_11_0_arm64.whl (289 kB)
# Downloading safetensors-0.7.0-cp38-abi3-macosx_11_0_arm64.whl (447 kB)
# Installing collected packages: safetensors, regex, hf-xet, huggingface-hub, tokenizers, transformers, sentence-transformers
#   Attempting uninstall: regex
#     Found existing installation: regex 2024.11.6
#     Uninstalling regex-2024.11.6:
#       Successfully uninstalled regex-2024.11.6
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7/7 [sentence-transformers]ence-transformers]
# Successfully installed hf-xet-1.4.3 huggingface-hub-1.9.2 regex-2026.4.4 safetensors-0.7.0 sentence-transformers-5.3.0 tokenizers-0.22.2 transformers-5.5.1
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install chromadb
# Out:
# Collecting chromadb
#   Downloading chromadb-1.5.7-cp39-abi3-macosx_11_0_arm64.whl.metadata (5.0 kB)
# Collecting build>=1.0.3 (from chromadb)
#   Downloading build-1.4.2-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: pydantic>=2.0 in /opt/anaconda3/lib/python3.13/site-packages (from chromadb) (2.10.3)
# Requirement already satisfied: pydantic-settings>=2.0 in /opt/anaconda3/lib/python3.13/site-packages (from chromadb) (2.13.1)
# Collecting pybase64>=1.4.1 (from chromadb)
#   Downloading pybase64-1.4.3-cp313-cp313-macosx_11_0_arm64.whl.metadata (8.7 kB)
# Requirement already satisfied: uvicorn>=0.18.3 in /opt/anaconda3/lib/python3.13/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.42.0)
# Requirement already satisfied: numpy>=1.22.5 in /opt/anaconda3/lib/python3.13/site-packages (from chromadb) (2.1.3)
# Requirement already satisfied: typing-extensions>=4.5.0 in /opt/anaconda3/lib/python3.13/site-packages (from chromadb) (4.15.0)
# Collecting onnxruntime>=1.14.1 (from chromadb)
#   Downloading onnxruntime-1.24.4-cp313-cp313-macosx_14_0_arm64.whl.metadata (5.2 kB)
# Collecting opentelemetry-api>=1.2.0 (from chromadb)
#   Downloading opentelemetry_api-1.40.0-py3-none-any.whl.metadata (1.5 kB)
# Collecting opentelemetry-exporter-otlp-proto-grpc>=1.2.0 (from chromadb)
#   Downloading opentelemetry_exporter_otlp_proto_grpc-1.40.0-py3-none-any.whl.metadata (2.6 kB)
# Collecting opentelemetry-sdk>=1.2.0 (from chromadb)
#   Downloading opentelemetry_sdk-1.40.0-py3-none-any.whl.metadata (1.6 kB)
# Requirement already satisfied: tokenizers>=0.13.2 in /opt/anaconda3/lib/python3.13/site-packages (from chromadb) (0.22.2)
# Collecting pypika>=0.48.9 (from chromadb)
#   Downloading pypika-0.51.1-py2.py3-none-any.whl.metadata (51 kB)
# Requirement already satisfied: tqdm>=4.65.0 in /opt/anaconda3/lib/python3.13/site-packages (from chromadb) (4.67.1)
# Requirement already satisfied: overrides>=7.3.1 in /opt/anaconda3/lib/python3.13/site-packages (from chromadb) (7.4.0)
# Collecting importlib-resources (from chromadb)
#   Downloading importlib_resources-6.5.2-py3-none-any.whl.metadata (3.9 kB)
# Requirement already satisfied: grpcio>=1.58.0 in /opt/anaconda3/lib/python3.13/site-packages (from chromadb) (1.76.0)
# Requirement already satisfied: bcrypt>=4.0.1 in /opt/anaconda3/lib/python3.13/site-packages (from chromadb) (4.3.0)
# Requirement already satisfied: typer>=0.9.0 in /opt/anaconda3/lib/python3.13/site-packages (from chromadb) (0.9.0)
# Collecting kubernetes>=28.1.0 (from chromadb)
#   Downloading kubernetes-35.0.0-py2.py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: tenacity>=8.2.3 in /opt/anaconda3/lib/python3.13/site-packages (from chromadb) (9.0.0)
# Requirement already satisfied: pyyaml>=6.0.0 in /opt/anaconda3/lib/python3.13/site-packages (from chromadb) (6.0.2)
# Collecting mmh3>=4.0.1 (from chromadb)
#   Downloading mmh3-5.2.1-cp313-cp313-macosx_11_0_arm64.whl.metadata (14 kB)
# Requirement already satisfied: orjson>=3.9.12 in /opt/anaconda3/lib/python3.13/site-packages (from chromadb) (3.11.8)
# Requirement already satisfied: httpx>=0.27.0 in /opt/anaconda3/lib/python3.13/site-packages (from chromadb) (0.28.1)
# Requirement already satisfied: rich>=10.11.0 in /opt/anaconda3/lib/python3.13/site-packages (from chromadb) (13.9.4)
# Requirement already satisfied: jsonschema>=4.19.0 in /opt/anaconda3/lib/python3.13/site-packages (from chromadb) (4.23.0)
# Requirement already satisfied: packaging>=24.0 in /opt/anaconda3/lib/python3.13/site-packages (from build>=1.0.3->chromadb) (24.2)
# Collecting pyproject_hooks (from build>=1.0.3->chromadb)
#   Downloading pyproject_hooks-1.2.0-py3-none-any.whl.metadata (1.3 kB)
# Requirement already satisfied: anyio in /opt/anaconda3/lib/python3.13/site-packages (from httpx>=0.27.0->chromadb) (4.7.0)
# Requirement already satisfied: certifi in /opt/anaconda3/lib/python3.13/site-packages (from httpx>=0.27.0->chromadb) (2025.10.5)
# Requirement already satisfied: httpcore==1.* in /opt/anaconda3/lib/python3.13/site-packages (from httpx>=0.27.0->chromadb) (1.0.9)
# Requirement already satisfied: idna in /opt/anaconda3/lib/python3.13/site-packages (from httpx>=0.27.0->chromadb) (3.7)
# Requirement already satisfied: h11>=0.16 in /opt/anaconda3/lib/python3.13/site-packages (from httpcore==1.*->httpx>=0.27.0->chromadb) (0.16.0)
# Requirement already satisfied: attrs>=22.2.0 in /opt/anaconda3/lib/python3.13/site-packages (from jsonschema>=4.19.0->chromadb) (24.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /opt/anaconda3/lib/python3.13/site-packages (from jsonschema>=4.19.0->chromadb) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in /opt/anaconda3/lib/python3.13/site-packages (from jsonschema>=4.19.0->chromadb) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /opt/anaconda3/lib/python3.13/site-packages (from jsonschema>=4.19.0->chromadb) (0.22.3)
# Requirement already satisfied: six>=1.9.0 in /opt/anaconda3/lib/python3.13/site-packages (from kubernetes>=28.1.0->chromadb) (1.17.0)
# Requirement already satisfied: python-dateutil>=2.5.3 in /opt/anaconda3/lib/python3.13/site-packages (from kubernetes>=28.1.0->chromadb) (2.9.0.post0)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in /opt/anaconda3/lib/python3.13/site-packages (from kubernetes>=28.1.0->chromadb) (1.8.0)
# Requirement already satisfied: requests in /opt/anaconda3/lib/python3.13/site-packages (from kubernetes>=28.1.0->chromadb) (2.33.1)
# Collecting requests-oauthlib (from kubernetes>=28.1.0->chromadb)
#   Downloading requests_oauthlib-2.0.0-py2.py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: urllib3!=2.6.0,>=1.24.2 in /opt/anaconda3/lib/python3.13/site-packages (from kubernetes>=28.1.0->chromadb) (2.3.0)
# Collecting durationpy>=0.7 (from kubernetes>=28.1.0->chromadb)
#   Downloading durationpy-0.10-py3-none-any.whl.metadata (340 bytes)
# Requirement already satisfied: flatbuffers in /opt/anaconda3/lib/python3.13/site-packages (from onnxruntime>=1.14.1->chromadb) (25.9.23)
# Requirement already satisfied: protobuf in /opt/anaconda3/lib/python3.13/site-packages (from onnxruntime>=1.14.1->chromadb) (6.33.2)
# Requirement already satisfied: sympy in /opt/anaconda3/lib/python3.13/site-packages (from onnxruntime>=1.14.1->chromadb) (1.13.3)
# Requirement already satisfied: importlib-metadata<8.8.0,>=6.0 in /opt/anaconda3/lib/python3.13/site-packages (from opentelemetry-api>=1.2.0->chromadb) (8.5.0)
# Requirement already satisfied: zipp>=3.20 in /opt/anaconda3/lib/python3.13/site-packages (from importlib-metadata<8.8.0,>=6.0->opentelemetry-api>=1.2.0->chromadb) (3.21.0)
# Requirement already satisfied: googleapis-common-protos~=1.57 in /opt/anaconda3/lib/python3.13/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.72.0)
# Collecting opentelemetry-exporter-otlp-proto-common==1.40.0 (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb)
#   Downloading opentelemetry_exporter_otlp_proto_common-1.40.0-py3-none-any.whl.metadata (1.9 kB)
# Collecting opentelemetry-proto==1.40.0 (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb)
#   Downloading opentelemetry_proto-1.40.0-py3-none-any.whl.metadata (2.4 kB)
# Collecting opentelemetry-semantic-conventions==0.61b0 (from opentelemetry-sdk>=1.2.0->chromadb)
#   Downloading opentelemetry_semantic_conventions-0.61b0-py3-none-any.whl.metadata (2.5 kB)
# Requirement already satisfied: annotated-types>=0.6.0 in /opt/anaconda3/lib/python3.13/site-packages (from pydantic>=2.0->chromadb) (0.6.0)
# Requirement already satisfied: pydantic-core==2.27.1 in /opt/anaconda3/lib/python3.13/site-packages (from pydantic>=2.0->chromadb) (2.27.1)
# Requirement already satisfied: python-dotenv>=0.21.0 in /opt/anaconda3/lib/python3.13/site-packages (from pydantic-settings>=2.0->chromadb) (1.1.0)
# Requirement already satisfied: typing-inspection>=0.4.0 in /opt/anaconda3/lib/python3.13/site-packages (from pydantic-settings>=2.0->chromadb) (0.4.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /opt/anaconda3/lib/python3.13/site-packages (from rich>=10.11.0->chromadb) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /opt/anaconda3/lib/python3.13/site-packages (from rich>=10.11.0->chromadb) (2.19.1)
# Requirement already satisfied: mdurl~=0.1 in /opt/anaconda3/lib/python3.13/site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->chromadb) (0.1.0)
# Requirement already satisfied: huggingface-hub<2.0,>=0.16.4 in /opt/anaconda3/lib/python3.13/site-packages (from tokenizers>=0.13.2->chromadb) (1.9.2)
# Requirement already satisfied: filelock>=3.10.0 in /opt/anaconda3/lib/python3.13/site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (3.17.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /opt/anaconda3/lib/python3.13/site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (2025.3.2)
# Requirement already satisfied: hf-xet<2.0.0,>=1.4.3 in /opt/anaconda3/lib/python3.13/site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (1.4.3)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /opt/anaconda3/lib/python3.13/site-packages (from typer>=0.9.0->chromadb) (8.3.1)
# Collecting httptools>=0.6.3 (from uvicorn[standard]>=0.18.3->chromadb)
#   Downloading httptools-0.7.1-cp313-cp313-macosx_11_0_arm64.whl.metadata (3.5 kB)
# Collecting uvloop>=0.15.1 (from uvicorn[standard]>=0.18.3->chromadb)
#   Downloading uvloop-0.22.1-cp313-cp313-macosx_10_13_universal2.whl.metadata (4.9 kB)
# Collecting watchfiles>=0.20 (from uvicorn[standard]>=0.18.3->chromadb)
#   Downloading watchfiles-1.1.1-cp313-cp313-macosx_11_0_arm64.whl.metadata (4.9 kB)
# Requirement already satisfied: websockets>=10.4 in /opt/anaconda3/lib/python3.13/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (16.0)
# Requirement already satisfied: sniffio>=1.1 in /opt/anaconda3/lib/python3.13/site-packages (from anyio->httpx>=0.27.0->chromadb) (1.3.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/anaconda3/lib/python3.13/site-packages (from requests->kubernetes>=28.1.0->chromadb) (3.3.2)
# Requirement already satisfied: oauthlib>=3.0.0 in /opt/anaconda3/lib/python3.13/site-packages (from requests-oauthlib->kubernetes>=28.1.0->chromadb) (3.3.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/anaconda3/lib/python3.13/site-packages (from sympy->onnxruntime>=1.14.1->chromadb) (1.3.0)
# Downloading chromadb-1.5.7-cp39-abi3-macosx_11_0_arm64.whl (21.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.3/21.3 MB 22.3 MB/s eta 0:00:00a 0:00:01
# Downloading build-1.4.2-py3-none-any.whl (24 kB)
# Downloading kubernetes-35.0.0-py2.py3-none-any.whl (2.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 16.2 MB/s eta 0:00:00
# Downloading durationpy-0.10-py3-none-any.whl (3.9 kB)
# Downloading mmh3-5.2.1-cp313-cp313-macosx_11_0_arm64.whl (40 kB)
# Downloading onnxruntime-1.24.4-cp313-cp313-macosx_14_0_arm64.whl (17.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.3/17.3 MB 26.2 MB/s eta 0:00:00a 0:00:01
# Downloading opentelemetry_api-1.40.0-py3-none-any.whl (68 kB)
# Downloading opentelemetry_exporter_otlp_proto_grpc-1.40.0-py3-none-any.whl (20 kB)
# Downloading opentelemetry_exporter_otlp_proto_common-1.40.0-py3-none-any.whl (18 kB)
# Downloading opentelemetry_proto-1.40.0-py3-none-any.whl (72 kB)
# Downloading opentelemetry_sdk-1.40.0-py3-none-any.whl (141 kB)
# Downloading opentelemetry_semantic_conventions-0.61b0-py3-none-any.whl (231 kB)
# Downloading pybase64-1.4.3-cp313-cp313-macosx_11_0_arm64.whl (31 kB)
# Downloading pypika-0.51.1-py2.py3-none-any.whl (60 kB)
# Downloading httptools-0.7.1-cp313-cp313-macosx_11_0_arm64.whl (108 kB)
# Downloading uvloop-0.22.1-cp313-cp313-macosx_10_13_universal2.whl (1.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 18.4 MB/s eta 0:00:00
# Downloading watchfiles-1.1.1-cp313-cp313-macosx_11_0_arm64.whl (391 kB)
# Downloading importlib_resources-6.5.2-py3-none-any.whl (37 kB)
# Downloading pyproject_hooks-1.2.0-py3-none-any.whl (10 kB)
# Downloading requests_oauthlib-2.0.0-py2.py3-none-any.whl (24 kB)
# Installing collected packages: pypika, durationpy, uvloop, pyproject_hooks, pybase64, opentelemetry-proto, mmh3, importlib-resources, httptools, watchfiles, requests-oauthlib, opentelemetry-exporter-otlp-proto-common, opentelemetry-api, onnxruntime, build, opentelemetry-semantic-conventions, kubernetes, opentelemetry-sdk, opentelemetry-exporter-otlp-proto-grpc, chromadb
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 20/20 [chromadb]/20 [chromadb]s]antic-conventions]
# Successfully installed build-1.4.2 chromadb-1.5.7 durationpy-0.10 httptools-0.7.1 importlib-resources-6.5.2 kubernetes-35.0.0 mmh3-5.2.1 onnxruntime-1.24.4 opentelemetry-api-1.40.0 opentelemetry-exporter-otlp-proto-common-1.40.0 opentelemetry-exporter-otlp-proto-grpc-1.40.0 opentelemetry-proto-1.40.0 opentelemetry-sdk-1.40.0 opentelemetry-semantic-conventions-0.61b0 pybase64-1.4.3 pypika-0.51.1 pyproject_hooks-1.2.0 requests-oauthlib-2.0.0 uvloop-0.22.1 watchfiles-1.1.1
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install gdown
# Out:
# Collecting gdown
#   Downloading gdown-5.2.1-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: beautifulsoup4 in /opt/anaconda3/lib/python3.13/site-packages (from gdown) (4.12.3)
# Requirement already satisfied: filelock in /opt/anaconda3/lib/python3.13/site-packages (from gdown) (3.17.0)
# Requirement already satisfied: requests[socks] in /opt/anaconda3/lib/python3.13/site-packages (from gdown) (2.33.1)
# Requirement already satisfied: tqdm in /opt/anaconda3/lib/python3.13/site-packages (from gdown) (4.67.1)
# Requirement already satisfied: soupsieve>1.2 in /opt/anaconda3/lib/python3.13/site-packages (from beautifulsoup4->gdown) (2.5)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/anaconda3/lib/python3.13/site-packages (from requests[socks]->gdown) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/lib/python3.13/site-packages (from requests[socks]->gdown) (3.7)
# Requirement already satisfied: urllib3<3,>=1.26 in /opt/anaconda3/lib/python3.13/site-packages (from requests[socks]->gdown) (2.3.0)
# Requirement already satisfied: certifi>=2023.5.7 in /opt/anaconda3/lib/python3.13/site-packages (from requests[socks]->gdown) (2025.10.5)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /opt/anaconda3/lib/python3.13/site-packages (from requests[socks]->gdown) (1.7.1)
# Downloading gdown-5.2.1-py3-none-any.whl (18 kB)
# Installing collected packages: gdown
# Successfully installed gdown-5.2.1
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # 2. Import all the necessary libararies

# %%
import os
import sys
from dotenv import load_dotenv
import gdown
import glob

from pydantic import BaseModel, Field
from langchain_core.prompts import PromptTemplate
from langchain_openai import ChatOpenAI
from langchain_community.document_loaders import PyPDFLoader
from langchain_text_splitters import RecursiveCharacterTextSplitter
from langchain_community.embeddings import HuggingFaceEmbeddings
from langchain_community.vectorstores import Chroma

# %%
# Load environment variables from a .env file
load_dotenv()

# Set the OpenAI API key environment variable
os.environ["OPENAI_API_KEY"] = os.getenv('OPENAI_API_KEY')

# %% [markdown]
# # 3. Define files path and encode

# %%
# 1. Define the folder ID from Gdrive
folder_url = 'https://drive.google.com/drive/folders/1J3pquKRB0GcBfjTd9qQjk_dqCTngNynV'
output_dir = 'data'

# 2. Create the directory if it doesn't exist
os.makedirs(output_dir, exist_ok=True)

# 3. Use gdown to download the entire folder
# 'quiet=False' allows you to see the progress bar
try:
    print("Starting download from Google Drive...")
    gdown.download_folder(url=folder_url, output=output_dir, quiet=False, remaining_ok=True)
    print(f"\nSuccess! Files saved to the '{output_dir}' folder.")
except Exception as e:
    print(f"An error occurred: {e}")
# Out:
# Starting download from Google Drive...
# Retrieving folder contents
# Processing file 1_P61rwtsPdC7Mxyn-dJdGTJQaQJz2aSS 2013-annual-performance-report.pdf
# Processing file 1YjZ3i5Xvj8wurzrjAI2VC1Dwh87u6_ue 2014-annual-performance-report.pdf
# Processing file 1VQwJ5zWdnkUx3cvZg-uGuFeehGgvvWw6 2015-annual-performance-report.pdf
# Processing file 1Z7EQs3qRvtZkvaVz-Ki-Sj-p0CZvDx7U 2016-annual-performance-report.pdf
# Processing file 1MZiqFWqaWsFZSuLg3X7_FZIYnmJO_jKV 2017-annual-performance-report.pdf
# Processing file 1maBBEWyZMARS7gOkKgc72HKb8GIIhVWR 2018-annual-performance-report.pdf
# Processing file 1WtvlqTGUTCZMZHZOwbSFaX8VULtQiLkg 2019-annual-performance-report.pdf
# Processing file 1C4oi3wr6q1vafdGH1mXP-zyb-tIXSFp1 2020-annual-performance-report.pdf
# Processing file 1QVKTKX-rtl8ZKyFDG42JQRmmc3wUXruD 2021-annual-performance-report.pdf
# Processing file 16JmmdBmk6_fDnZT-bQEQGUehXpEH3Gc4 2022-annual-performance-report.pdf
# Processing file 1f4lGR-z53blOmTjfK5WSV7jbvP37bmuY DHS2020.pdf
# Processing file 1I5ysTlkRD_PIwtblJ06oE8-_JUIKbKyR DOC2022.pdf
# Processing file 1D4CXy6MTiGQRqyP3gVVzEdRzl2QRv_G- DOL2022.pdf
# Processing file 17gtM83XW7Rb6dGfOd8BkFEIprdpbuS6j DOSAID2022.pdf
# Processing file 1CoOApnGT4EXdDdnxRzNsU693U8byZoh3 DOT2022.pdf
# Processing file 1NXrj17MEQ5lwKX54n17V9QI0mzl0xFZa EDAPP2022.pdf
# Processing file 1upBKe-7iz5xLpU5FcOeDxiZz9SDEKAay EPA2022.pdf
# Processing file 148JDzEq82CbYAzQhqH0Wwqf-9wZEZS2m GSA2022.pdf
# Processing file 1AKIe6BaDcTUx9m99RCml7QxvS6VTPB-k HHS2022.pdf
# Processing file 1ncasNadn8xtn2AI-pae3UDgs1aePpUIm NARA2022.pdf
# Retrieving folder contents completed
# Building directory structure
# Building directory structure completed
# Downloading...
# From: https://drive.google.com/uc?id=1_P61rwtsPdC7Mxyn-dJdGTJQaQJz2aSS
# To: /Users/mlinggar/Documents/Kampus/Hyper Den/data/2013-annual-performance-report.pdf
# 100%|██████████| 1.27M/1.27M [00:00<00:00, 20.7MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1YjZ3i5Xvj8wurzrjAI2VC1Dwh87u6_ue
# To: /Users/mlinggar/Documents/Kampus/Hyper Den/data/2014-annual-performance-report.pdf
# 100%|██████████| 1.87M/1.87M [00:00<00:00, 22.2MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1VQwJ5zWdnkUx3cvZg-uGuFeehGgvvWw6
# To: /Users/mlinggar/Documents/Kampus/Hyper Den/data/2015-annual-performance-report.pdf
# 100%|██████████| 2.35M/2.35M [00:00<00:00, 26.8MB/s]
# Downloading...
# From (original): https://drive.google.com/uc?id=1Z7EQs3qRvtZkvaVz-Ki-Sj-p0CZvDx7U
# From (redirected): https://drive.google.com/uc?id=1Z7EQs3qRvtZkvaVz-Ki-Sj-p0CZvDx7U&confirm=t&uuid=36b8b866-df1a-4732-b688-f8f4982c1b73
# To: /Users/mlinggar/Documents/Kampus/Hyper Den/data/2016-annual-performance-report.pdf
# 100%|██████████| 3.37M/3.37M [00:00<00:00, 22.9MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1MZiqFWqaWsFZSuLg3X7_FZIYnmJO_jKV
# To: /Users/mlinggar/Documents/Kampus/Hyper Den/data/2017-annual-performance-report.pdf
# 100%|██████████| 2.20M/2.20M [00:00<00:00, 20.9MB/s]
# An error occurred: Failed to retrieve file url:
#
# 	Cannot retrieve the public link of the file. You may need to change
# 	the permission to 'Anyone with the link', or have had many accesses.
# 	Check FAQ in https://github.com/wkentaro/gdown?tab=readme-ov-file#faq.
#
# You may still be able to access the file from the browser:
#
# 	https://drive.google.com/uc?id=1maBBEWyZMARS7gOkKgc72HKb8GIIhVWR
#
# but Gdown can't. Please check connections and permissions.

# %%
# Create function to load, process, and encode PDF documents
def encode_pdf(file_path):
    print(f"Loading and processing: {file_path}...")
    loader = PyPDFLoader(file_path)
    docs = loader.load()
    
    text_splitter = RecursiveCharacterTextSplitter(chunk_size=1000, chunk_overlap=200)
    splits = text_splitter.split_documents(docs)
    
    embedding_model = HuggingFaceEmbeddings(model_name="all-MiniLM-L6-v2")
    vs = Chroma.from_documents(documents=splits, embedding=embedding_model)
    return vs

# %%
# 1. Get all PDF paths
pdf_files = glob.glob("data/*.pdf")

# 2. Loop through and process each one
for path in pdf_files:
    print(f"Now encoding: {path}")
    vectorstore = encode_pdf(path)
    
print("--- All PDFs processed! ---")
# Out:
# Now encoding: data/2013-annual-performance-report.pdf
# Loading and processing: data/2013-annual-performance-report.pdf...
# /var/folders/m6/kchw2h3943z39q2k6bmlw1f80000gn/T/ipykernel_3574/3952110872.py:9: LangChainDeprecationWarning: The class `HuggingFaceEmbeddings` was deprecated in LangChain 0.2.2 and will be removed in 1.0. An updated version of the class exists in the `langchain-huggingface package and should be used instead. To use it run `pip install -U `langchain-huggingface` and import as `from `langchain_huggingface import HuggingFaceEmbeddings``.
#   embedding_model = HuggingFaceEmbeddings(model_name="all-MiniLM-L6-v2")
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# Loading weights:   0%|          | 0/103 [00:00<?, ?it/s]
# BertModel LOAD REPORT from: sentence-transformers/all-MiniLM-L6-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED:	can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# Now encoding: data/2020-annual-performance-report.pdf
# Loading and processing: data/2020-annual-performance-report.pdf...
# Loading weights:   0%|          | 0/103 [00:00<?, ?it/s]
# BertModel LOAD REPORT from: sentence-transformers/all-MiniLM-L6-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED:	can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# Now encoding: data/DOT2022.pdf
# Loading and processing: data/DOT2022.pdf...
# Loading weights:   0%|          | 0/103 [00:00<?, ?it/s]
# BertModel LOAD REPORT from: sentence-transformers/all-MiniLM-L6-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED:	can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# Now encoding: data/2014-annual-performance-report.pdf
# Loading and processing: data/2014-annual-performance-report.pdf...
# Loading weights:   0%|          | 0/103 [00:00<?, ?it/s]
# BertModel LOAD REPORT from: sentence-transformers/all-MiniLM-L6-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED:	can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# Now encoding: data/DOSAID2022.pdf
# Loading and processing: data/DOSAID2022.pdf...
# Loading weights:   0%|          | 0/103 [00:00<?, ?it/s]
# BertModel LOAD REPORT from: sentence-transformers/all-MiniLM-L6-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED:	can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# Now encoding: data/DOC2022.pdf
# Loading and processing: data/DOC2022.pdf...
# Loading weights:   0%|          | 0/103 [00:00<?, ?it/s]
# BertModel LOAD REPORT from: sentence-transformers/all-MiniLM-L6-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED:	can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# Now encoding: data/EPA2022.pdf
# Loading and processing: data/EPA2022.pdf...
# Loading weights:   0%|          | 0/103 [00:00<?, ?it/s]
# BertModel LOAD REPORT from: sentence-transformers/all-MiniLM-L6-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED:	can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# Now encoding: data/2015-annual-performance-report.pdf
# Loading and processing: data/2015-annual-performance-report.pdf...
# Loading weights:   0%|          | 0/103 [00:00<?, ?it/s]
# BertModel LOAD REPORT from: sentence-transformers/all-MiniLM-L6-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED:	can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# Now encoding: data/GSA2022.pdf
# Loading and processing: data/GSA2022.pdf...
# Loading weights:   0%|          | 0/103 [00:00<?, ?it/s]
# BertModel LOAD REPORT from: sentence-transformers/all-MiniLM-L6-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED:	can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# Now encoding: data/2021-annual-performance-report.pdf
# Loading and processing: data/2021-annual-performance-report.pdf...
# Loading weights:   0%|          | 0/103 [00:00<?, ?it/s]
# BertModel LOAD REPORT from: sentence-transformers/all-MiniLM-L6-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED:	can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# Now encoding: data/NARA2022.pdf
# Loading and processing: data/NARA2022.pdf...
# Loading weights:   0%|          | 0/103 [00:00<?, ?it/s]
# BertModel LOAD REPORT from: sentence-transformers/all-MiniLM-L6-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED:	can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# Now encoding: data/HHS2022.pdf
# Loading and processing: data/HHS2022.pdf...
# Loading weights:   0%|          | 0/103 [00:00<?, ?it/s]
# BertModel LOAD REPORT from: sentence-transformers/all-MiniLM-L6-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED:	can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# Now encoding: data/2016-annual-performance-report.pdf
# Loading and processing: data/2016-annual-performance-report.pdf...
# Loading weights:   0%|          | 0/103 [00:00<?, ?it/s]
# BertModel LOAD REPORT from: sentence-transformers/all-MiniLM-L6-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED:	can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# Now encoding: data/2022-annual-performance-report.pdf
# Loading and processing: data/2022-annual-performance-report.pdf...
# Loading weights:   0%|          | 0/103 [00:00<?, ?it/s]
# BertModel LOAD REPORT from: sentence-transformers/all-MiniLM-L6-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED:	can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# Now encoding: data/2019-annual-performance-report.pdf
# Loading and processing: data/2019-annual-performance-report.pdf...
# Loading weights:   0%|          | 0/103 [00:00<?, ?it/s]
# BertModel LOAD REPORT from: sentence-transformers/all-MiniLM-L6-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED:	can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# Now encoding: data/EDAPP2022.pdf
# Loading and processing: data/EDAPP2022.pdf...
# Loading weights:   0%|          | 0/103 [00:00<?, ?it/s]
# BertModel LOAD REPORT from: sentence-transformers/all-MiniLM-L6-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED:	can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# Now encoding: data/2018-annual-performance-report.pdf
# Loading and processing: data/2018-annual-performance-report.pdf...
# Loading weights:   0%|          | 0/103 [00:00<?, ?it/s]
# BertModel LOAD REPORT from: sentence-transformers/all-MiniLM-L6-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED:	can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# Now encoding: data/DHS2020.pdf
# Loading and processing: data/DHS2020.pdf...
# Loading weights:   0%|          | 0/103 [00:00<?, ?it/s]
# BertModel LOAD REPORT from: sentence-transformers/all-MiniLM-L6-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED:	can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# Now encoding: data/2017-annual-performance-report.pdf
# Loading and processing: data/2017-annual-performance-report.pdf...
# Loading weights:   0%|          | 0/103 [00:00<?, ?it/s]
# BertModel LOAD REPORT from: sentence-transformers/all-MiniLM-L6-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED:	can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# Now encoding: data/DOL2022.pdf
# Loading and processing: data/DOL2022.pdf...
# Loading weights:   0%|          | 0/103 [00:00<?, ?it/s]
# BertModel LOAD REPORT from: sentence-transformers/all-MiniLM-L6-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED:	can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# --- All PDFs processed! ---

# %% [markdown]
# # 4. Initialize the language model

# %%
llm = ChatOpenAI(model="gpt-4o-mini", max_tokens=1000, temperature=0)

# %% [markdown]
# # 5. Defining prompt templates

# %%
class RetrievalResponse(BaseModel):
    response: str = Field(..., title="Determines if retrieval is necessary", description="Output only 'Yes' or 'No'.")
retrieval_prompt = PromptTemplate(
    input_variables=["query"],
    template="Given the query '{query}', determine if retrieval is necessary. Output only 'Yes' or 'No'."
)

class RelevanceResponse(BaseModel):
    response: str = Field(..., title="Determines if context is relevant", description="Output only 'Relevant' or 'Irrelevant'.")
relevance_prompt = PromptTemplate(
    input_variables=["query", "context"],
    template="Given the query '{query}' and the context '{context}', determine if the context is relevant. Output only 'Relevant' or 'Irrelevant'."
)

class GenerationResponse(BaseModel):
    response: str = Field(..., title="Generated response", description="The generated response.")
generation_prompt = PromptTemplate(
    input_variables=["query", "context"],
    template="Given the query '{query}' and the context '{context}', generate a response."
)

class SupportResponse(BaseModel):
    response: str = Field(..., title="Determines if response is supported", description="Output 'Fully supported', 'Partially supported', or 'No support'.")
support_prompt = PromptTemplate(
    input_variables=["response", "context"],
    template="Given the response '{response}' and the context '{context}', determine if the response is supported by the context. Output 'Fully supported', 'Partially supported', or 'No support'."
)

class UtilityResponse(BaseModel):
    response: int = Field(..., title="Utility rating", description="Rate the utility of the response from 1 to 5.")
utility_prompt = PromptTemplate(
    input_variables=["query", "response"],
    template="Given the query '{query}' and the response '{response}', rate the utility of the response from 1 to 5."
)

# Create LLMChains for each step
retrieval_chain = retrieval_prompt | llm.with_structured_output(RetrievalResponse)
relevance_chain = relevance_prompt | llm.with_structured_output(RelevanceResponse)
generation_chain = generation_prompt | llm.with_structured_output(GenerationResponse)
support_chain = support_prompt | llm.with_structured_output(SupportResponse)
utility_chain = utility_prompt | llm.with_structured_output(UtilityResponse)

# %% [markdown]
# # 6.Defining the self RAG logic flow

# %%
def self_rag(query, vectorstore, top_k=3):
    print(f"\nProcessing query: {query}")
    
    # Step 1: Determine if retrieval is necessary
    print("Step 1: Determining if retrieval is necessary...")
    input_data = {"query": query}
    retrieval_decision = retrieval_chain.invoke(input_data).response.strip().lower()
    print(f"Retrieval decision: {retrieval_decision}")
    
    if retrieval_decision == 'yes':
        # Step 2: Retrieve relevant documents
        print("Step 2: Retrieving relevant documents...")
        docs = vectorstore.similarity_search(query, k=top_k)
        contexts = [doc.page_content for doc in docs]
        print(f"Retrieved {len(contexts)} documents")
        
        # Step 3: Evaluate relevance of retrieved documents
        print("Step 3: Evaluating relevance of retrieved documents...")
        relevant_contexts = []
        for i, context in enumerate(contexts):
            input_data = {"query": query, "context": context}
            relevance = relevance_chain.invoke(input_data).response.strip().lower()
            print(f"Document {i+1} relevance: {relevance}")
            if relevance == 'relevant':
                relevant_contexts.append(context)
        
        print(f"Number of relevant contexts: {len(relevant_contexts)}")
        
        # If no relevant contexts found, generate without retrieval
        if not relevant_contexts:
            print("No relevant contexts found. Generating without retrieval...")
            input_data = {"query": query, "context": "No relevant context found."}
            return generation_chain.invoke(input_data).response
        
        # Step 4: Generate response using relevant contexts
        print("Step 4: Generating responses using relevant contexts...")
        responses = []
        for i, context in enumerate(relevant_contexts):
            print(f"Generating response for context {i+1}...")
            input_data = {"query": query, "context": context}
            response = generation_chain.invoke(input_data).response
            
            # Step 5: Assess support
            print(f"Step 5: Assessing support for response {i+1}...")
            input_data = {"response": response, "context": context}
            support = support_chain.invoke(input_data).response.strip().lower()
            print(f"Support assessment: {support}")
            
            # Step 6: Evaluate utility
            print(f"Step 6: Evaluating utility for response {i+1}...")
            input_data = {"query": query, "response": response}
            utility = int(utility_chain.invoke(input_data).response)
            print(f"Utility score: {utility}")
            
            responses.append((response, support, utility))
        
        # Select the best response based on support and utility
        print("Selecting the best response...")
        best_response = max(responses, key=lambda x: (x[1] == 'fully supported', x[2]))
        print(f"Best response support: {best_response[1]}, utility: {best_response[2]}")
        return best_response[0]
    else:
        # Generate without retrieval
        print("Generating without retrieval...")
        input_data = {"query": query, "context": "No retrieval necessary."}
        return generation_chain.invoke(input_data).response

# %% [markdown]
# # 7. Test the self-RAG function easy query with high relevance

# %%
query = "What is the most important thing about the annual performance report in 2022?"
response = self_rag(query, vectorstore)

print("\nFinal response:")
print(response)
# Out:
# Processing query: What is the most important thing about the annual performance report in 2022?
# Step 1: Determining if retrieval is necessary...
# Retrieval decision: yes
# Step 2: Retrieving relevant documents...
# Retrieved 3 documents
# Step 3: Evaluating relevance of retrieved documents...
# Document 1 relevance: relevant
# Document 2 relevance: relevant
# Document 3 relevance: relevant
# Number of relevant contexts: 3
# Step 4: Generating responses using relevant contexts...
# Generating response for context 1...
# Step 5: Assessing support for response 1...
# Support assessment: fully supported
# Step 6: Evaluating utility for response 1...
# Utility score: 5
# Generating response for context 2...
# Step 5: Assessing support for response 2...
# Support assessment: fully supported
# Step 6: Evaluating utility for response 2...
# Utility score: 5
# Generating response for context 3...
# Step 5: Assessing support for response 3...
# Support assessment: fully supported
# Step 6: Evaluating utility for response 3...
# Utility score: 5
# Selecting the best response...
# Best response support: fully supported, utility: 5
#
# Final response:
# The most important aspect of the annual performance report in 2022 is its role in evaluating the agency's effectiveness in meeting its strategic objectives. The report not only outlines the performance measures and targets that were set based on resource allocation but also provides a comparison between the planned performance levels and the actual outcomes. This comparison is crucial as it highlights any variances or trends, allowing the agency to identify successful practices and areas needing improvement. Furthermore, the report serves as a tool for accountability, enabling Congress and stakeholders to assess the agency's progress and make informed decisions regarding future resource allocation and strategic direction.

# %% [markdown]
# # 8. Test the self-RAG function with a more challenging query with low relevance

# %%
query = "how did aragon beat sauron?"
response = self_rag(query, vectorstore)

print("\nFinal response:")
print(response)
# Out:
# Processing query: how did aragon beat sauron?
# Step 1: Determining if retrieval is necessary...
# Retrieval decision: no
# Generating without retrieval...
#
# Final response:
# Aragorn defeated Sauron not through direct combat, but by uniting the free peoples of Middle-earth and leading them in a strategic battle against Sauron's forces. In the climax of "The Lord of the Rings: The Return of the King," Aragorn, as the rightful heir to the throne of Gondor, rallies the armies of men, elves, and dwarves to confront Sauron's army at the Black Gate of Mordor.
#
# The key to their victory lies in the diversion created by Frodo and Sam's quest to destroy the One Ring in Mount Doom. As they approach the final confrontation, Sauron is distracted by the threat posed by Aragorn's forces, believing them to be the primary threat. This diversion allows Frodo to ultimately destroy the Ring, which leads to Sauron's downfall. Without the Ring, Sauron's power is shattered, and he is defeated, marking the end of his dark reign.

# %% [markdown]
# # 9. Try it your self
# ### (*please type ***exit*** or ***quit*** to exit the query*)

# %%
# Interactive loop for user queries
while True:
    # 1. Ask for input
    query = input("\nInput your query here (or type 'exit' to stop): ").strip()

    # 2. Check if the user wants to quit
    if query.lower() in ['exit', 'quit', 'q']:
        print("Closing the assistant. Goodbye!")
        break

    # 3. Skip empty inputs
    if not query:
        continue

    # 4. Run the RAG process
    try:
        response = self_rag(query, vectorstore)
        print("\n--- Final response ---")
        print(response)
    except Exception as e:
        print(f"An error occurred: {e}")
# Out:
# Processing query: what is the most important information from annual performace report in 2018 and 2019
# Step 1: Determining if retrieval is necessary...
# Retrieval decision: yes
# Step 2: Retrieving relevant documents...
# Retrieved 3 documents
# Step 3: Evaluating relevance of retrieved documents...
# Document 1 relevance: irrelevant
# Document 2 relevance: irrelevant
# Document 3 relevance: irrelevant
# Number of relevant contexts: 0
# No relevant contexts found. Generating without retrieval...
#
# --- Final response ---
# To provide a comprehensive answer regarding the most important information from the annual performance reports of 2018 and 2019, we would typically look for key metrics and highlights such as:
#
# 1. **Financial Performance**: This includes revenue growth, profit margins, and overall financial health indicators such as net income and earnings per share (EPS).
#
# 2. **Operational Efficiency**: Metrics related to productivity, cost management, and operational improvements that may have been implemented during these years.
#
# 3. **Market Position**: Changes in market share, customer acquisition, and retention rates, as well as any significant shifts in competitive positioning.
#
# 4. **Strategic Initiatives**: Information on any major projects, investments, or strategic shifts that were undertaken in these years, including mergers and acquisitions.
#
# 5. **Employee Performance and Engagement**: Insights into workforce metrics, employee satisfaction, and retention rates, which can indicate the health of the organizational culture.
#
# 6. **Sustainability and Corporate Social Responsibility (CSR)**: Any initiatives or progress made in sustainability efforts or CSR activities that reflect the company’s commitment to social and environmental responsibilities.
#
# 7. **Future Outlook**: Management’s commentary on future expectations, including forecasts, challenges, and opportunities that may impact performance moving forward.
#
# For specific details, one would need to access the actual annual performance reports for 2018 and 2019, as they would contain the exact figures and narratives that highlight these areas.
#
# Processing query: what is the most important thing for annual performance report in 2013
# Step 1: Determining if retrieval is necessary...
# Retrieval decision: yes
# Step 2: Retrieving relevant documents...
# Retrieved 3 documents
# Step 3: Evaluating relevance of retrieved documents...
# Document 1 relevance: relevant
# Document 2 relevance: irrelevant
# Document 3 relevance: irrelevant
# Number of relevant contexts: 1
# Step 4: Generating responses using relevant contexts...
# Generating response for context 1...
# Step 5: Assessing support for response 1...
# Support assessment: fully supported
# Step 6: Evaluating utility for response 1...
# Utility score: 5
# Selecting the best response...
# Best response support: fully supported, utility: 5
#
# --- Final response ---
# The most important thing for the Annual Performance Report in 2013 for the United States Office of Personnel Management (OPM) is to provide a comprehensive evaluation of the agency's performance against its strategic goals and objectives for that fiscal year. This includes assessing the effectiveness of programs, measuring outcomes, and demonstrating accountability to stakeholders. Key components typically include:
#
# 1. **Performance Metrics**: Clear data and statistics that reflect the agency's achievements and areas for improvement.
# 2. **Goal Alignment**: How the agency's activities align with broader federal goals and priorities.
# 3. **Challenges and Solutions**: Identification of challenges faced during the year and the strategies implemented to address them.
# 4. **Stakeholder Engagement**: Evidence of how the agency engaged with stakeholders and incorporated their feedback into its operations.
# 5. **Future Directions**: Insights into future goals and how the agency plans to enhance its performance moving forward.
#
# Overall, the report should serve as a transparent account of the agency's performance, highlighting successes and areas for growth.
#
# Processing query: give me relevant information for annual performance report 2015
# Step 1: Determining if retrieval is necessary...
# Retrieval decision: yes
# Step 2: Retrieving relevant documents...
# Retrieved 3 documents
# Step 3: Evaluating relevance of retrieved documents...
# Document 1 relevance: relevant
# Document 2 relevance: relevant
# Document 3 relevance: irrelevant
# Number of relevant contexts: 2
# Step 4: Generating responses using relevant contexts...
# Generating response for context 1...
# Step 5: Assessing support for response 1...
# Support assessment: fully supported
# Step 6: Evaluating utility for response 1...
# Utility score: 5
# Generating response for context 2...
# Step 5: Assessing support for response 2...
# Support assessment: fully supported
# Step 6: Evaluating utility for response 2...
# Utility score: 5
# Selecting the best response...
# Best response support: fully supported, utility: 5
#
# --- Final response ---
# The Annual Performance Report for Fiscal Year 2015 provides a comprehensive overview of the Office of Personnel Management's (OPM) performance metrics, goals, and achievements during that year. Key highlights include:
#
# 1. **Strategic Goals**: The report outlines OPM's strategic goals for 2015, focusing on enhancing workforce performance, improving employee engagement, and fostering a diverse and inclusive workplace.
#
# 2. **Performance Metrics**: It includes specific performance indicators that measure the effectiveness of OPM's programs and initiatives, such as recruitment and retention rates, employee satisfaction scores, and training program outcomes.
#
# 3. **Program Achievements**: The report details significant accomplishments in various areas, including the implementation of new hiring practices, advancements in employee training programs, and initiatives aimed at improving the overall employee experience.
#
# 4. **Challenges and Areas for Improvement**: It also addresses challenges faced during the year, such as budget constraints and the need for technological upgrades, along with strategies for overcoming these obstacles in future performance cycles.
#
# 5. **Financial Overview**: A financial summary is provided, detailing the budget allocation and expenditures related to OPM's programs and services.
#
# 6. **Future Goals**: The report concludes with a look ahead, outlining OPM's objectives for the upcoming fiscal year and how they plan to build on the successes and lessons learned from 2015.
#
# This report serves as a critical tool for stakeholders to assess OPM's effectiveness and accountability in managing federal workforce programs.
# Closing the assistant. Goodbye!
